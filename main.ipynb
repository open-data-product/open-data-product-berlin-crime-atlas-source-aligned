# %% [markdown]
# # Berlin LOR Crime Atlas (source-aligned) - Sample Notebook

# %% [markdown]
# ## Explore data

# %%
import pandas as pd        

# Read csv file
dataframe = pd.read_csv("./data/03-gold/berlin-crime-atlas-2023-00-csv/berlin-crime-atlas-2023-00-frequency-numbers-forecast-areas.csv")

# %%
# Display 5 first rows
dataframe.head()
# Out:
#     id  offences  robbery  street_robbery_purse_snatching  bodily_harm  \
# 0  110  118877.0   1089.0                           636.0      10403.0
# 1  120   37636.0    269.0                           161.0       3421.0
# 2  130   33611.0    412.0                           194.0       3804.0
# 3  140   31448.0    433.0                           271.0       3203.0
# 4  199       0.0      0.0                             0.0          0.0
#
#    dangerous_and_grievous_bodily_harm  \
# 0                              2729.0
# 1                               862.0
# 2                              1121.0
# 3                               983.0
# 4                                 0.0
#
#    deprivation_of_liberty_coercion_threat_stalking    theft  \
# 0                                           4572.0  56524.0
# 1                                           1587.0  14124.0
# 2                                           1742.0  14854.0
# ...

# %%
# Display dataframe info
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 18 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   id                                               70 non-null     int64
#  1   offences                                         70 non-null     float64
#  2   robbery                                          70 non-null     float64
#  3   street_robbery_purse_snatching                   70 non-null     float64
#  4   bodily_harm                                      70 non-null     float64
#  5   dangerous_and_grievous_bodily_harm               70 non-null     float64
#  6   deprivation_of_liberty_coercion_threat_stalking  70 non-null     float64
#  7   theft                                            70 non-null     float64
#  8   motor_vehicle_theft                              70 non-null     float64
# ...

# %%
# Describe dataframe
dataframe.describe()
# Out:
#                 id       offences      robbery  \
# count    70.000000      70.000000    70.000000
# mean    686.542857   23808.214286   252.714286
# std     349.335505   20333.469241   254.536985
# min     110.000000       0.000000     0.000000
# 25%     377.250000   12224.750000    87.000000
# 50%     704.500000   21340.000000   212.500000
# 75%     986.750000   30024.750000   340.500000
# max    1299.000000  118877.000000  1410.000000
#
#        street_robbery_purse_snatching   bodily_harm  \
# count                       70.000000     70.000000
# mean                       155.671429   2398.385714
# std                        166.076176   1892.606479
# min                          0.000000      0.000000
# 25%                         64.750000   1168.750000
# 50%                        122.500000   2271.000000
# 75%                        193.250000   3411.500000
# max                       1016.000000  10403.000000
#
#        dangerous_and_grievous_bodily_harm  \
# ...
